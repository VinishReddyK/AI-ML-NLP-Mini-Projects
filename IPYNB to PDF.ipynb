# %% [markdown]
# ## Directly convert to pdf

# %% [markdown]
# Only works on google colab
# upload the file and rename the file name below

# %%
# !jupyter nbconvert --to html "File_Name.ipynb"
# Out:
# [NbConvertApp] Converting notebook NLP_Project.ipynb to html

# %% [markdown]
# Hit Ctrl+p after opening the generated HTML and save as PDF
